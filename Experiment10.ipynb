# %% [markdown]
# Python Experiment 10:

# %%
## Question 1:

# %%
import numpy as np

arr = np.array([10, 20, 30, 40, 50])

print("Array:", arr)
print("Sum of elements:", np.sum(arr))

arr = np.array([10, 20, 30, 40, 50])

print("Array:", arr)
print("Sum of elements:", np.sum(arr))
